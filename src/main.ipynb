# %%
#Import libraries
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager # sustituye al archivo
from selenium.webdriver.common.by import By # By es para buscar por tag, clase, id...
import time
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
PATH = ChromeDriverManager().install()    # instala driver de chrome

driver = webdriver.Chrome(PATH)      # abre una ventana de chrome

#Busqueda didn´t work, I had to type up the whole URL + search

URL='https://www.booking.com/searchresults.es.html?ss=Chamart%C3%ADn&ssne=Chamart%C3%ADn&ssne_untouched=Chamart%C3%ADn&efdco=1&label=gen173nr-1BCBkoggI46AdIM1gEaEaIAQGYAQq4ARfIAQzYAQHoAQGIAgGoAgO4AvPn46IGwAIB0gIkOTFmYzYxYTAtYjc3NC00NDM5LWIwNTgtOWIyNGIwYjRiZDA52AIF4AIB&sid=d4b5462ce9ae6cf55f51b42829c8b5ed&aid=304142&lang=es&sb=1&src_elem=sb&src=searchresults&dest_id=180&dest_type=district&checkin=2023-05-08&checkout=2023-05-09&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&flex_window=1'

driver.get(URL)

time.sleep(3)

driver.find_element(By.XPATH, '//*[@id="onetrust-reject-all-handler"]').click()  # rechaza cookies

# %%
tabla = driver.find_elements(By.CLASS_NAME, 'd20f4628d0')

filas = [e.text.split('\n') for e in tabla]

filas
# Out:
# [['Ilunion Pio XII',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapa',
#   'Nivel 3 del programa de Viajes sostenibles',
#   '8,3',
#   'Muy bien',
#   '9.142 comentarios',
#   'Oferta Escapada',
#   'Habitación Doble - 1 o 2 camas',
#   'Camas: 1 doble o 2 individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 149€ 119',
#   'Precio original € 149. Precio actual € 119.',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Hotel Chamartin The One',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   '8,1',
#   'Muy bien',
#   '10.393 comentarios',
#   'Habitación Doble',
#   '1 cama doble',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 140',
#   'Precio € 140',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Crisol Vía Castellana',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
# ...

# %%
filas_dict = {} #Creates a dictionary with name of accomodation and price.

for i in filas:
    name = i[0].replace('-', '')
    price = i[-3][-3:].strip('.')
    filas_dict[name] = price

filas_dict
# Out:
# {'Ilunion Pio XII': '19',
#  'Hotel Chamartin The One': '140',
#  'Crisol Vía Castellana': '140',
#  'Roisa Hostal Boutique': ' 95',
#  'La Posada de El Chaflán': '72',
#  'Ilunion Suites Madrid': '52',
#  'NH Paseo de la Habana': '227',
#  'Hotel Puerta America': '205',
#  'Sercotel Togumar': '143',
#  'Barceló Imagine': '263',
#  'NUEVOS DUPLEX PRINCIPE VERGARA': '120',
#  'Hostal Madrid Paradise': ' 39',
#  'UVE Marcenado': '119',
#  'AC Hotel Aitana by Marriott': '308',
#  'Desayuno incluido': '405',
#  'Hostel Thirty One 31': ' 34',
#  'Don Pio': '175',
#  'Hotel 4C Puerta Europa': ' 80',
#  'Avenida De America Tijcal': ' 79',
#  'NH Madrid Balboa': '156',
#  'LooP America': ' 48',
#  'Abba Madrid': '105',
#  'Chamberí Suites': '154',
#  'MA Estudio San German': ' 84',
#  'AC Hotel Avenida de América by Marriott': '178'}

# %%
# Column names
cabeceras = ['name', 'price']

# Creates DF from dictionary
df_booking = pd.DataFrame.from_dict(filas_dict, orient='index')
df_booking = df_booking.reset_index()
df_booking.columns = cabeceras
df_booking = df_booking.rename(columns={'index': 'acc_id'})

# change data type of 'age' column to integer
df_booking = df_booking.astype({'price': int})

df_booking
# Out:
#                                        name  price
# 0                           Ilunion Pio XII     19
# 1                   Hotel Chamartin The One    140
# 2                     Crisol Vía Castellana    140
# 3                     Roisa Hostal Boutique     95
# 4                   La Posada de El Chaflán     72
# 5                     Ilunion Suites Madrid     52
# 6                     NH Paseo de la Habana    227
# 7                      Hotel Puerta America    205
# 8                          Sercotel Togumar    143
# 9                           Barceló Imagine    263
# 10           NUEVOS DUPLEX PRINCIPE VERGARA    120
# 11                   Hostal Madrid Paradise     39
# 12                            UVE Marcenado    119
# 13              AC Hotel Aitana by Marriott    308
# 14                        Desayuno incluido    405
# 15                     Hostel Thirty One 31     34
# 16                                  Don Pio    175
# ...

# %%
#Adds a column for storing source of data
df_booking['web'] = 'Booking.com'
df_booking['distrito'] = 'Chamartín'
df_booking
# Out:
#                                        name  price          web   distrito
# 0                           Ilunion Pio XII     19  Booking.com  Chamartín
# 1                   Hotel Chamartin The One    140  Booking.com  Chamartín
# 2                     Crisol Vía Castellana    140  Booking.com  Chamartín
# 3                     Roisa Hostal Boutique     95  Booking.com  Chamartín
# 4                   La Posada de El Chaflán     72  Booking.com  Chamartín
# 5                     Ilunion Suites Madrid     52  Booking.com  Chamartín
# 6                     NH Paseo de la Habana    227  Booking.com  Chamartín
# 7                      Hotel Puerta America    205  Booking.com  Chamartín
# 8                          Sercotel Togumar    143  Booking.com  Chamartín
# 9                           Barceló Imagine    263  Booking.com  Chamartín
# 10           NUEVOS DUPLEX PRINCIPE VERGARA    120  Booking.com  Chamartín
# ...

# %%
#Load csv file into a DF
df_bb_listing=pd.read_csv('../data/listings.csv')
df_bb_listing.sample(10)
# Out:
#              id                                               name    host_id  \
# 18473  47252174     Habitación con Balcón, hotel Posada del Dragón  381583058
# 3600   15278012              Habitación en Lavapiés, Madrid centro   38603361
# 13682  39213662                                             DIVA 1    7145793
# 14698  40885775           Pretty Bedroom little in Lavapies Madrid   60492971
# 6351   21953821                     Lujo en el barrio de Salamanca  160190461
# 16533  43594251  Amplio y encantador piso a tres minutos del me...  114027648
# 79       289555                 Casa Museo del Prado-Private room.     901218
# 18267  46597055                               Estudio (2 personas)  376738237
# 12968  37315944          Habitación en centro de Madrid (Malasaña)  137721834
# 10937  34636625  Room with privileged view in the center of Madrid   64636177
#
#           host_name    neighbourhood_group neighbourhood  latitude  longitude  \
# ...

# %%
#Checks shape
df_bb_listing.shape
# Out:
# (19618, 16)

# %%
#Clean nulls and duplicates.
df_bb_listing = df_bb_listing.dropna().drop_duplicates()
#Checks shape
df_bb_listing.shape
# Out:
# (13584, 16)

# %%
df_bb_listing.neighbourhood_group.value_counts()
# Out:
# Centro                   6599
# Salamanca                 854
# Arganzuela                776
# Chamberí                  735
# Tetuán                    525
# Retiro                    477
# Carabanchel               437
# Ciudad Lineal             417
# Puente de Vallecas        413
# Chamartín                 378
# Moncloa - Aravaca         375
# Latina                    363
# Hortaleza                 246
# San Blas - Canillejas     231
# Fuencarral - El Pardo     196
# Usera                     186
# Barajas                   109
# Villaverde                101
# Villa de Vallecas          67
# Moratalaz                  61
# Vicálvaro                  38
# Name: neighbourhood_group, dtype: int64

# %%
#Drop rows where neighbourhood_group is not Chamartín
chamartin=[r for index, r in df_bb_listing.iterrows() if r['neighbourhood_group']=='Chamartín']
df_chamartin_bb = pd.DataFrame(chamartin)
df_chamartin_bb
# Out:
#              id                                               name    host_id  \
# 0          6369           Rooftop terrace room ,  ensuite bathroom      13660
# 91       337292                    Principe de Vergara. Homey Room    1714866
# 97       342557    Berlin's Park at your window. Parking included.    1738288
# 167      544736                     SUNNY & EASY ACCESIBLE BEDROOM    1284868
# 197      616027                Quiet room well located, Av.America    3053021
# ...         ...                                                ...        ...
# 18917  47936837    Cozy Private Housing Rental in shared apartment  369379555
# 18985  48049256  Nuevo/acogedor estudio en Prosperidad con terraza    9885245
# 19089  48204816            Beautiful & cozy apartment in Bernabeu!  388923241
# 19324  48672492          HABITACION/ESTUDIO  Entrada independiente  364849660
# 19375  48794295  GRAN HABITACION INDIVIDUAL BUENA ZONA Y COMUNI...    1284868
#
# ...

# %%
#Keep columns name and price, adds a column called web where source is stored
df_bb = df_chamartin_bb.loc[:, ['name', 'price']].assign(web='Air B&B', distrito='Chamartín')
type(df_bb.price[0])
# Out:
# numpy.int64

# %%
df_bb = df_bb.reset_index(drop=True)
df_bb
# Out:
#                                                   name  price      web  \
# 0             Rooftop terrace room ,  ensuite bathroom     60  Air B&B
# 1                      Principe de Vergara. Homey Room     35  Air B&B
# 2      Berlin's Park at your window. Parking included.     70  Air B&B
# 3                       SUNNY & EASY ACCESIBLE BEDROOM     21  Air B&B
# 4                  Quiet room well located, Av.America     23  Air B&B
# ..                                                 ...    ...      ...
# 373    Cozy Private Housing Rental in shared apartment     27  Air B&B
# 374  Nuevo/acogedor estudio en Prosperidad con terraza     34  Air B&B
# 375            Beautiful & cozy apartment in Bernabeu!     40  Air B&B
# 376          HABITACION/ESTUDIO  Entrada independiente     36  Air B&B
# 377  GRAN HABITACION INDIVIDUAL BUENA ZONA Y COMUNI...     19  Air B&B
#
#       distrito
# 0    Chamartín
# 1    Chamartín
# 2    Chamartín
# 3    Chamartín
# 4    Chamartín
# ..         ...
# ...

# %%
#Load csv file into a DF
df_distritos = pd.read_csv('../data/Distritos_Lat_Lon.csv')
df_distritos
# Out:
#                  DISTRITO;LATITUD;LONGITUD
# 0                 Centro;40.41831;-3.70275
# 1             Arganzuela;40.40021;-3.69618
# 2                Retiro;40.41317 ;-3.68307
# 3             Salamanca;40.42972 ;-3.67975
# 4               Chamartín;40.46206;-3.6766
# 5                  Tetuan;40.45975;-3.6975
# 6               Chamberi;40.43404;-3.70379
# 7     Fuencarral-El Pardo;40.4984 ;-3.7314
# 8         Moncloa-Aravaca;40.43547;-3.7317
# 9                 Latina;40.38897;-3.74569
# 10            Carabanchel;40.39094;-3.7242
# 11                 Usera;40.38866;-3.70035
# 12     Puente De Vallecas;40.39354 ;-3.662
# 13           Moratalaz;40.40742 ;-3.664935
# 14        Ciudad Lineal;40.44505 ;-3.65132
# 15              Hortaleza;40.47444;-3.6411
# 16                   Villaverde;40.35;-3.7
# 17        Villa de Vallecas;40.374;-3.6122
# 18              Vicalvaro;40.394 ;-3.60288
# 19  San Blas-Canillejas;40.43893 ;-3.61537
# 20           Barajas;40.4736600;-3.5777700

# %%
# Split the values in the column in three separate columns
df_distritos[['distrito', 'latitud', 'longitud']] = df_distritos['DISTRITO;LATITUD;LONGITUD'].str.split(';', expand=True)

# Drop the original column 
df_distritos.drop('DISTRITO;LATITUD;LONGITUD', axis=1, inplace=True)
print(df_distritos.info())
df_distritos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   distrito  21 non-null     object
#  1   latitud   21 non-null     object
#  2   longitud  21 non-null     object
# dtypes: object(3)
# memory usage: 632.0+ bytes
# None
#                distrito     latitud    longitud
# 0                Centro    40.41831    -3.70275
# 1            Arganzuela    40.40021    -3.69618
# 2                Retiro   40.41317     -3.68307
# 3             Salamanca   40.42972     -3.67975
# 4             Chamartín    40.46206     -3.6766
# 5                Tetuan    40.45975     -3.6975
# 6              Chamberi    40.43404    -3.70379
# 7   Fuencarral-El Pardo    40.4984      -3.7314
# 8       Moncloa-Aravaca    40.43547     -3.7317
# 9                Latina    40.38897    -3.74569
# 10          Carabanchel    40.39094     -3.7242
# ...

# %%
#Export to sql

#Import SQL Alchemy.
from sqlalchemy import create_engine

#Creates connection
str_conn = 'mysql+pymysql://root:Juanco55@127.0.0.1:3306/accommodations'

cursor = create_engine(str_conn)

#RESPETAR JERARQUIA MADRE-HIJA

#Inserta datos en df_category.
df_distritos.to_sql(name='distritos', 
            con=cursor,
            if_exists='append',   
            index=False
           )

#Inserta datos en df_language.
df_bb.to_sql(name='Air_B&B', 
            con=cursor,
            if_exists='append',   
            index=False
           )

#Inserta datos en df_actor.
df_booking.to_sql(name='Booking', 
            con=cursor,
            if_exists='append',   
            index=False
           )
# Out:
# 25
