# %%
#Import libraries
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager # sustituye al archivo
from selenium.webdriver.common.by import By # By es para buscar por tag, clase, id...
import time
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
PATH = ChromeDriverManager().install()    # instala driver de chrome

driver = webdriver.Chrome(PATH)      # abre una ventana de chrome

#Busqueda didn´t work, I had to type up the whole URL + search

URL='https://www.booking.com/searchresults.es.html?ss=Chamart%C3%ADn&ssne=Chamart%C3%ADn&ssne_untouched=Chamart%C3%ADn&efdco=1&label=gen173nr-1BCBkoggI46AdIM1gEaEaIAQGYAQq4ARfIAQzYAQHoAQGIAgGoAgO4AvPn46IGwAIB0gIkOTFmYzYxYTAtYjc3NC00NDM5LWIwNTgtOWIyNGIwYjRiZDA52AIF4AIB&sid=d4b5462ce9ae6cf55f51b42829c8b5ed&aid=304142&lang=es&sb=1&src_elem=sb&src=searchresults&dest_id=180&dest_type=district&checkin=2023-05-08&checkout=2023-05-09&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&flex_window=1'

driver.get(URL)

time.sleep(3)

driver.find_element(By.XPATH, '//*[@id="onetrust-reject-all-handler"]').click()  # rechaza cookies

# %%
tabla = driver.find_elements(By.CLASS_NAME, 'd20f4628d0')

filas = [e.text.split('\n') for e in tabla]

filas
# Out:
# [['Apartamentos Torr',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapa',
#   'Nivel 1 del programa de Viajes sostenibles',
#   '7,1',
#   'Bien',
#   '337 comentarios',
#   'Apartamento de 1 dormitorio',
#   'Apartamento entero • 1 dormitorio • 1 sala de estar • 1 baño • 1 cocina • 55m²',
#   '3 camas (2 individuales, 1 sofá cama)',
#   'Solo quedan 3 a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 84',
#   'Precio € 84',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Roisa Hostal Boutique',
#   'Se abre en una ventana nueva',
#   'Promocionado',
#   'Este establecimiento paga un poco más para promocionarse en nuestra página. Cumple con tus criterios de búsqueda y es una muy buena opción.',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 2 del programa de Viajes sostenibles',
#   '8,0',
#   'Muy bien',
#   '2.863 comentarios',
#   'Habitación Doble Superior - 2 camas',
#   '2 camas individuales',
#   'Solo queda 1 habitación a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 100',
#   'Precio € 100',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['La Posada de El Chaflán',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapa',
#   'Nivel 1 del programa de Viajes sostenibles',
#   '7,0',
#   'Bien',
#   '1.474 comentarios',
#   'Oferta Escapada',
#   'Habitación Doble',
#   '1 cama doble',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 90€ 72',
#   'Precio original € 90. Precio actual € 72.',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Desayuno incluido',
#   'Real Rooms',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 1 del programa de Viajes sostenibles',
#   '8,3',
#   'Muy bien',
#   '430 comentarios',
#   'Habitación Doble con baño privado - 1 o 2 camas',
#   'Camas: 1 doble o 2 individuales',
#   'Desayuno incluido',
#   'Solo queda 1 habitación a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 86',
#   'Precio € 86',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Ilunion Pio XII',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapa',
#   'Nivel 3 del programa de Viajes sostenibles',
#   '8,3',
#   'Muy bien',
#   '9.136 comentarios',
#   'Oferta Escapada',
#   'Habitación Doble - 1 o 2 camas',
#   'Camas: 1 doble o 2 individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 149€ 119',
#   'Precio original € 149. Precio actual € 119.',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Crisol Vía Castellana',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 3 del programa de Viajes sostenibles',
#   '8,2',
#   'Muy bien',
#   '5.098 comentarios',
#   'Habitación Doble Clásica - 1 o 2 camas',
#   'Camas: 1 doble o 2 individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 140',
#   'Precio € 140',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Hotel Chamartin The One',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   '8,1',
#   'Muy bien',
#   '10.393 comentarios',
#   'Habitación Doble - 1 o 2 camas',
#   '2 camas individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 150',
#   'Precio € 150',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Hotel Puerta America',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 3 del programa de Viajes sostenibles',
#   '8,4',
#   'Muy bien',
#   '5.105 comentarios',
#   'Habitación Deluxe',
#   'Camas: 1 doble o 2 individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 205',
#   'Precio € 205',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['NH Paseo de la Habana',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 2 del programa de Viajes sostenibles',
#   '7,8',
#   'Bien',
#   '2.081 comentarios',
#   'Habitación Doble Estándar New Style - 1 o 2 camas',
#   '1 cama doble',
#   'Solo quedan 4 habitaciones a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 251',
#   'Precio € 251',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Ilunion Suites Madrid',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapa',
#   'Nivel 3 del programa de Viajes sostenibles',
#   '8,5',
#   'Muy bien',
#   '6.691 comentarios',
#   'Oferta Escapada',
#   'Habitación Doble Estándar - 1 o 2 camas',
#   'Camas: 1 doble o 2 individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 190€ 152',
#   'Precio original € 190. Precio actual € 152.',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Sercotel Togumar',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 1 del programa de Viajes sostenibles',
#   '8,3',
#   'Muy bien',
#   '1.764 comentarios',
#   'Habitación Doble - 2 camas',
#   '2 camas individuales',
#   'Solo quedan 2 habitaciones a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 143',
#   'Precio € 143',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Hostel Thirty One 31',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   '5,9',
#   'Puntuación',
#   '384 comentarios',
#   '2×',
#   'Litera en habitación compartida mixta',
#   '2 camas en habitación compartida',
#   '2 camas individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 34',
#   'Precio € 34',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['AC Hotel Aitana by Marriott',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 1 del programa de Viajes sostenibles',
#   '8,8',
#   'Fabuloso',
#   '748 comentarios',
#   'Habitación Estándar - 1 cama grande',
#   '1 cama doble grande',
#   'Solo queda 1 habitación a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 275',
#   'Precio € 275',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Estudios Apartamentos Torr',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapa',
#   '7,5',
#   'Bien',
#   '64 comentarios',
#   'Estudio',
#   'Estudio entero • 1 baño • 1 cocina • 40m²',
#   '2 camas individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 79',
#   'Precio € 79',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Hostal Madrid Paradise',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   '6,5',
#   'Puntuación',
#   '556 comentarios',
#   '1×',
#   'Cama en habitación compartida mixta de 6 camas',
#   'Cama en habitación compartida',
#   '1 cama individual',
#   '1×',
#   'Cama en habitación compartida mixta de 4 camas',
#   'Cama en habitación compartida',
#   '1 cama individual',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 41',
#   'Precio € 41',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Apartamentos Olano C.B.',
#   'Se abre en una ventana nueva',
#   'Gestionado por un particular',
#   'Chamartín, MadridMostrar en el mapa',
#   '8,4',
#   'Muy bien',
#   '187 comentarios',
#   'Apartamento de 1 dormitorio (2 adultos)',
#   '2 camas individuales',
#   'Solo queda 1 habitación a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 95',
#   'Precio € 95',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['UVE Marcenado',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 1 del programa de Viajes sostenibles',
#   '9,2',
#   'Fantástico',
#   '2.371 comentarios',
#   'Habitación Doble - 2 camas',
#   '2 camas individuales',
#   'Solo quedan 2 habitaciones a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 119',
#   'Precio € 119',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Barceló Imagine',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 1 del programa de Viajes sostenibles',
#   '9,1',
#   'Fantástico',
#   '2.815 comentarios',
#   'Habitación Doble Deluxe - 1 o 2 camas',
#   'Camas: 1 doble o 2 individuales',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 263',
#   'Precio € 263',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Desayuno incluido',
#   'NH Collection Madrid Eurobuilding',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 2 del programa de Viajes sostenibles',
#   '8,9',
#   'Fabuloso',
#   '1.709 comentarios',
#   'Habitación Doble Superior - 1 o 2 camas',
#   'Camas: 1 doble o 2 individuales',
#   'Desayuno incluido',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 405',
#   'Precio € 405',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['NUEVOS DUPLEX PRINCIPE VERGARA',
#   'Se abre en una ventana nueva',
#   'Promocionado',
#   'Este establecimiento paga un poco más para promocionarse en nuestra página. Cumple con tus criterios de búsqueda y es una muy buena opción.',
#   'Chamartín, MadridMostrar en el mapa',
#   '6,9',
#   'Puntuación',
#   '428 comentarios',
#   'Loft Deluxe',
#   'Apartamento entero • 1 dormitorio • 1 sala de estar • 2 baños • 1 cocina • 69m²',
#   '3 camas (1 doble, 2 sofás cama)',
#   'Solo queda 1 a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 120',
#   'Precio € 120',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['dobohomes - Clara del Rey 33',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   '6,8',
#   'Puntuación',
#   '6 comentarios',
#   'Estudio Deluxe',
#   'Estudio entero • 1 baño • 25m²',
#   '2 camas individuales',
#   'Solo queda 1 a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 115',
#   'Precio € 115',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Don Pio',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   '8,6',
#   'Fabuloso',
#   '392 comentarios',
#   'Habitación Doble - 1 o 2 camas',
#   'Camas: 1 doble o 2 individuales',
#   'Solo quedan 3 habitaciones a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 175',
#   'Precio € 175',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['My City Home - Acogedor apartamento en Canillas VI',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   '9,6',
#   'Excepcional',
#   '7 comentarios',
#   'Apartamento de 1 dormitorio',
#   'Apartamento entero • 1 dormitorio • 1 baño • 25m²',
#   '1 cama doble',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 190',
#   'Precio € 190',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Apartamentos Torr Av América - López de Hoyos',
#   'Se abre en una ventana nueva',
#   'Chamartín, MadridMostrar en el mapaCerca del metro',
#   'Nivel 1 del programa de Viajes sostenibles',
#   '7,7',
#   'Bien',
#   '31 comentarios',
#   'Apartamento',
#   'Apartamento entero • 3 dormitorios • 1 sala de estar • 2 baños • 1 cocina • 120m²',
#   '7 camas (6 dobles, 1 sofá cama)',
#   'Solo queda 1 a este precio en nuestra web',
#   'mar, 9 may - mié, 10 may',
#   '1 noche, 2 adultos',
#   '€ 800',
#   'Precio € 800',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad'],
#  ['Hotel 4C Puerta Europa',
#   'Se abre en una ventana nueva',
#   'Tetuán, MadridMostrar en el mapaCerca del metro',
#   '7,8',
#   'Bien',
#   '1.283 comentarios',
#   'Habitación Doble - 2 camas',
#   '2 camas individuales',
#   'Solo queda 1 habitación a este precio en nuestra web',
#   'lun, 8 may - mar, 9 may',
#   '1 noche, 2 adultos',
#   '€ 80',
#   'Precio € 80',
#   'Incluye impuestos y cargos',
#   'Ver disponibilidad']]

# %%
filas_dict = {} #Creates a dictionary with name of accomodation and price.

for i in filas:
    name = i[0].replace('-', '')
    price = i[-3][-3:].strip('.')
    filas_dict[name] = price

filas_dict
# Out:
# {'Apartamentos Torr': ' 84',
#  'Roisa Hostal Boutique': '100',
#  'La Posada de El Chaflán': '72',
#  'Desayuno incluido': '405',
#  'Ilunion Pio XII': '19',
#  'Crisol Vía Castellana': '140',
#  'Hotel Chamartin The One': '150',
#  'Hotel Puerta America': '205',
#  'NH Paseo de la Habana': '251',
#  'Ilunion Suites Madrid': '52',
#  'Sercotel Togumar': '143',
#  'Hostel Thirty One 31': ' 34',
#  'AC Hotel Aitana by Marriott': '275',
#  'Estudios Apartamentos Torr': ' 79',
#  'Hostal Madrid Paradise': ' 41',
#  'Apartamentos Olano C.B.': ' 95',
#  'UVE Marcenado': '119',
#  'Barceló Imagine': '263',
#  'NUEVOS DUPLEX PRINCIPE VERGARA': '120',
#  'dobohomes  Clara del Rey 33': '115',
#  'Don Pio': '175',
#  'My City Home  Acogedor apartamento en Canillas VI': '190',
#  'Apartamentos Torr Av América  López de Hoyos': '800',
#  'Hotel 4C Puerta Europa': ' 80'}

# %%
# Column names
cabeceras = ['name', 'price']

# Creates DF from dictionary
df_booking = pd.DataFrame.from_dict(filas_dict, orient='index')
df_booking = df_booking.reset_index()
df_booking.columns = cabeceras
df_booking = df_booking.rename(columns={'index': 'acc_id'})

# change data type of 'age' column to integer
df_booking = df_booking.astype({'price': int})

df_booking
# Out:
#                                                  name  price
# 0                                   Apartamentos Torr     84
# 1                               Roisa Hostal Boutique    100
# 2                             La Posada de El Chaflán     72
# 3                                   Desayuno incluido    405
# 4                                     Ilunion Pio XII     19
# 5                               Crisol Vía Castellana    140
# 6                             Hotel Chamartin The One    150
# 7                                Hotel Puerta America    205
# 8                               NH Paseo de la Habana    251
# 9                               Ilunion Suites Madrid     52
# 10                                   Sercotel Togumar    143
# 11                               Hostel Thirty One 31     34
# 12                        AC Hotel Aitana by Marriott    275
# 13                         Estudios Apartamentos Torr     79
# 14                             Hostal Madrid Paradise     41
# 15                            Apartamentos Olano C.B.     95
# 16                                      UVE Marcenado    119
# 17                                    Barceló Imagine    263
# 18                     NUEVOS DUPLEX PRINCIPE VERGARA    120
# 19                        dobohomes  Clara del Rey 33    115
# 20                                            Don Pio    175
# 21  My City Home  Acogedor apartamento en Canillas VI    190
# 22       Apartamentos Torr Av América  López de Hoyos    800
# 23                             Hotel 4C Puerta Europa     80

# %%
#Adds a column for storing source of data
df_booking['web'] = 'Booking.com'
df_booking
# Out:
#                                                  name  price          web
# 0                                   Apartamentos Torr     84  Booking.com
# 1                               Roisa Hostal Boutique    100  Booking.com
# 2                             La Posada de El Chaflán     72  Booking.com
# 3                                   Desayuno incluido    405  Booking.com
# 4                                     Ilunion Pio XII     19  Booking.com
# 5                               Crisol Vía Castellana    140  Booking.com
# 6                             Hotel Chamartin The One    150  Booking.com
# 7                                Hotel Puerta America    205  Booking.com
# 8                               NH Paseo de la Habana    251  Booking.com
# 9                               Ilunion Suites Madrid     52  Booking.com
# 10                                   Sercotel Togumar    143  Booking.com
# 11                               Hostel Thirty One 31     34  Booking.com
# 12                        AC Hotel Aitana by Marriott    275  Booking.com
# 13                         Estudios Apartamentos Torr     79  Booking.com
# 14                             Hostal Madrid Paradise     41  Booking.com
# 15                            Apartamentos Olano C.B.     95  Booking.com
# 16                                      UVE Marcenado    119  Booking.com
# 17                                    Barceló Imagine    263  Booking.com
# 18                     NUEVOS DUPLEX PRINCIPE VERGARA    120  Booking.com
# 19                        dobohomes  Clara del Rey 33    115  Booking.com
# 20                                            Don Pio    175  Booking.com
# 21  My City Home  Acogedor apartamento en Canillas VI    190  Booking.com
# 22       Apartamentos Torr Av América  López de Hoyos    800  Booking.com
# 23                             Hotel 4C Puerta Europa     80  Booking.com

# %%
#Load csv file into a DF
df_bb_listing=pd.read_csv('data/listings.csv')
df_bb_listing.sample(10)
# Out:
#              id                                               name    host_id  \
# 10571  34056883    Fomen: Apartamento super tranquilo en el centro   13612054
# 7120   23945344                                    home sweet home   36206961
# 9551   31191551                                        Los yebenes  142765755
# 7827   26289105                                 La casita de David  145704629
# 19375  48794295  GRAN HABITACION INDIVIDUAL BUENA ZONA Y COMUNI...    1284868
# 4358   17692661                            Piso bonito en Chamberì   27027172
# 12663  36552052       habitacion en alquiler ciudad de los angeles  274777754
# 2713   12278791                 Family & Bright, Central Apartment   44267738
# 209      659887           Habitación amplia y comoda centro Madrid    3329487
# 9968   32357176           Charming Vintage Studio in trendy Chueca  231647798
#
#             host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 10571         Maribel              Centro       Palacio  40.42078   -3.71198
# 7120             Alex              Centro   Embajadores  40.41123   -3.70186
# 9551             Jose              Latina        Aluche  40.39200   -3.75008
# 7827            David  Puente de Vallecas     Entrevías  40.38151   -3.67747
# 19375           Rocio           Chamartín  Nueva España  40.45919   -3.67665
# 4358         Fabrizia            Chamberí       Almagro  40.43337   -3.69289
# 12663          Miguel          Villaverde   Los Angeles  40.35337   -3.69806
# 2713   Madrid Central              Centro        Cortes  40.41219   -3.69637
# 209           Nicolás              Retiro      Pacífico  40.40264   -3.68309
# 9968            Akora              Centro      Justicia  40.42328   -3.69551
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 10571  Entire home/apt     50              15                  7  2020-10-23
# 7120   Entire home/apt     54               1                 23  2020-03-20
# 9551      Private room     29               2                  0         NaN
# 7827      Private room     24               1                 65  2021-01-15
# 19375     Private room     19               2                  1  2021-03-28
# 4358   Entire home/apt    120               5                 19  2020-03-01
# 12663      Shared room    250               1                  0         NaN
# 2713   Entire home/apt   1139               1                154  2019-11-08
# 209       Private room     29              14                  5  2018-12-30
# 9968   Entire home/apt     47               1                 17  2020-03-02
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 10571               0.32                               2               214
# 7120                0.62                               1               365
# 9551                 NaN                               1                 0
# 7827                1.94                               4               165
# 19375               1.00                               3               333
# 4358                0.40                               1               357
# 12663                NaN                               1               365
# 2713                2.57                              27                 0
# 209                 0.08                               2               364
# 9968                0.71                              10               308

# %%
#Checks shape
df_bb_listing.shape
# Out:
# (19618, 16)

# %%
#Clean nulls and duplicates.
df_bb_listing = df_bb_listing.dropna().drop_duplicates()
#Checks shape
df_bb_listing.shape
# Out:
# (13584, 16)

# %%
df_bb_listing.neighbourhood_group.value_counts()
# Out:
# Centro                   6599
# Salamanca                 854
# Arganzuela                776
# Chamberí                  735
# Tetuán                    525
# Retiro                    477
# Carabanchel               437
# Ciudad Lineal             417
# Puente de Vallecas        413
# Chamartín                 378
# Moncloa - Aravaca         375
# Latina                    363
# Hortaleza                 246
# San Blas - Canillejas     231
# Fuencarral - El Pardo     196
# Usera                     186
# Barajas                   109
# Villaverde                101
# Villa de Vallecas          67
# Moratalaz                  61
# Vicálvaro                  38
# Name: neighbourhood_group, dtype: int64

# %%
#Drop rows where neighbourhood_group is not Chamartín
chamartin=[r for index, r in df_bb_listing.iterrows() if r['neighbourhood_group']=='Chamartín']
df_chamartin_bb = pd.DataFrame(chamartin)
df_chamartin_bb
# Out:
#              id                                               name    host_id  \
# 0          6369           Rooftop terrace room ,  ensuite bathroom      13660
# 91       337292                    Principe de Vergara. Homey Room    1714866
# 97       342557    Berlin's Park at your window. Parking included.    1738288
# 167      544736                     SUNNY & EASY ACCESIBLE BEDROOM    1284868
# 197      616027                Quiet room well located, Av.America    3053021
# ...         ...                                                ...        ...
# 18917  47936837    Cozy Private Housing Rental in shared apartment  369379555
# 18985  48049256  Nuevo/acogedor estudio en Prosperidad con terraza    9885245
# 19089  48204816            Beautiful & cozy apartment in Bernabeu!  388923241
# 19324  48672492          HABITACION/ESTUDIO  Entrada independiente  364849660
# 19375  48794295  GRAN HABITACION INDIVIDUAL BUENA ZONA Y COMUNI...    1284868
#
#            host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0              Simon           Chamartín  Hispanoamérica  40.45724   -3.67688
# 91         Francisco           Chamartín   Ciudad Jardín  40.44663   -3.67625
# 97        Jose Angel           Chamartín   Ciudad Jardín  40.45005   -3.67569
# 167            Rocio           Chamartín  Hispanoamérica  40.45841   -3.67598
# 197            Sonia           Chamartín     Prosperidad  40.43922   -3.67574
# ...              ...                 ...             ...       ...        ...
# 18917        Vitoria           Chamartín  Hispanoamérica  40.45661   -3.68066
# 18985  My Mad Madrid           Chamartín   Ciudad Jardín  40.44704   -3.67156
# 19089          Keren           Chamartín    Nueva España  40.46165   -3.68668
# 19324           Eric           Chamartín   Ciudad Jardín  40.44999   -3.66736
# 19375          Rocio           Chamartín    Nueva España  40.45919   -3.67665
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room     60               1                 78  2020-09-20
# 91        Private room     35               2                  7  2017-04-18
# 97        Private room     70               2                 55  2019-11-03
# 167       Private room     21               2                 37  2021-03-31
# 197       Private room     23               1                 74  2018-09-19
# ...                ...    ...             ...                ...         ...
# 18917     Private room     27               1                  2  2021-03-31
# 18985  Entire home/apt     34               2                  2  2021-04-10
# 19089  Entire home/apt     40               1                  1  2021-03-29
# 19324     Private room     36               2                  3  2021-04-07
# 19375     Private room     19               2                  1  2021-03-28
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.58                               1               180
# 91                  0.07                               1                 0
# 97                  0.60                               1               343
# 167                 0.39                               3               311
# 197                 0.71                               1                 0
# ...                  ...                             ...               ...
# 18917               0.80                               1               305
# 18985               2.00                              38               354
# 19089               1.00                               1                77
# 19324               3.00                               1               336
# 19375               1.00                               3               333
#
# [378 rows x 16 columns]

# %%
#Keep columns name and price, adds a column called web where source is stored
df_bb = df_chamartin_bb.loc[:, ['name', 'price']].assign(web='Air B&B')
type(df_bb.price[0])
# Out:
# numpy.int64

# %%
df_bb = df_bb.reset_index(drop=True)
df_bb
# Out:
#                                                   name  price      web
# 0             Rooftop terrace room ,  ensuite bathroom     60  Air B&B
# 1                      Principe de Vergara. Homey Room     35  Air B&B
# 2      Berlin's Park at your window. Parking included.     70  Air B&B
# 3                       SUNNY & EASY ACCESIBLE BEDROOM     21  Air B&B
# 4                  Quiet room well located, Av.America     23  Air B&B
# ..                                                 ...    ...      ...
# 373    Cozy Private Housing Rental in shared apartment     27  Air B&B
# 374  Nuevo/acogedor estudio en Prosperidad con terraza     34  Air B&B
# 375            Beautiful & cozy apartment in Bernabeu!     40  Air B&B
# 376          HABITACION/ESTUDIO  Entrada independiente     36  Air B&B
# 377  GRAN HABITACION INDIVIDUAL BUENA ZONA Y COMUNI...     19  Air B&B
#
# [378 rows x 3 columns]
